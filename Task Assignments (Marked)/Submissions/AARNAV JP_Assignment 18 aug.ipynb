# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ebf94183-e8d6-411e-805f-77e9431b8105" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebf94183-e8d6-411e-805f-77e9431b8105">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance.csv to insurance.csv

# %%
df=pd.read_csv('insurance.csv')
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
df.shape
# Out:
# (28, 3)

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def sigmoid_der(x):
    return sigmoid(x)*(1-sigmoid(x))

# %%
feature_set=df.drop('bought_insurance',axis=1)
labels=np.array(df['bought_insurance'])
labels=labels.reshape(28,1)

# %%
np.random.seed(50)
weights=np.random.rand(2,1)
bias=np.random.rand(1)
lr=0.001

# %%
for epoch in range(30000):
    inputs=feature_set
    
    y=np.dot(feature_set,weights)+bias
    z=sigmoid(y)
    
    error=z-labels
    print(error.sum())
    
    dcost_dpred=error
    dpred_dz=sigmoid_der(z)
    
    z_delta=dcost_dpred*dpred_dz
    
    inputs=feature_set.T
    weights-=lr*np.dot(inputs,z_delta)
    
    for num in z_delta:
        bias-=lr*num
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.13073492416200927
# 0.1307224118407101
# 0.13070990051540854
# 0.13069739018599036
# 0.1306848808523241
# 0.13067237251432584
# 0.13065986517187345
# 0.130647358824852
# 0.13063485347314185
# 0.13062234911666937
# 0.13060984575526535
# 0.13059734338888662
# 0.1305848420173501
# 0.13057234164060172
# 0.13055984225849837
# 0.13054734387093725
# 0.1305348464778281
# 0.13052235007901236
# 0.1305098546744342
# 0.13049736026393688
# 0.13048486684742688
# 0.1304723744247972
# 0.13045988299593836
# 0.1304473925607289
# 0.13043490311906003
# 0.1304224146708426
# 0.1304099272159236
# 0.13039744075422743
# 0.13038495528562355
# 0.1303724708100088
# 0.13035998732727583
# 0.13034750483731872
# 0.13033502334000324
# 0.13032254283522948
# 0.13031006332290906
# 0.13029758480289044
# 0.130285107275098
# 0.1302726307394031
# 0.130260155195684
# 0.13024768064387426
# 0.13023520708380776
# 0.13022273451540212
# 0.1302102629385652
# ...

# %%
#person with age 53 and affordibility 0
single_point=np.array([53,0])
result=sigmoid(np.dot(single_point,weights)+bias)
print(result)
# Out:
# [0.58685231]

# %%
#person with age 21 and affordibility 1
single_point=np.array([21,1])
result=sigmoid(np.dot(single_point,weights)+bias)
print(result)
# Out:
# [0.15506755]
