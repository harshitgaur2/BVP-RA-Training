# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ayush1103-hub/BVP-RA-Training/main/Assignment%201/Task/insurance_data.csv")
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
a = df.drop(columns = 'bought_insurance')
b = df['bought_insurance']

# %%
feature_set = a.to_numpy()
labels = b.to_numpy()
labels = labels.reshape(28,1)

# %%
np.random.seed(35)
weights = np.random.rand(2,1)
bias = np.random.rand(1)
lr = 0.001

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_der(x):
    return sigmoid(x) * (1-sigmoid(x))

# %%
for epoch in range(20000):
  inputs = feature_set

  XW = np.dot(feature_set, weights) + bias

  z = sigmoid(XW)

  error = z - labels

  print(error.sum())

  dcost_dpred = error
  dpred_dz = sigmoid_der(z)

  z_delta = dcost_dpred * dpred_dz

  inputs = feature_set.T
  weights -= lr * np.dot(inputs, z_delta)

  for num in z_delta:
        bias -= lr * num
# Out:
# 13.999455003033702
# 13.997403484115978
# 13.98715679755114
# 13.933190804525015
# 13.628514075188027
# 11.62044347160543
# -0.668702041224461
# 9.50702748759825
# -3.1161088869224285
# 11.309677689667458
# -1.4390009897158338
# 10.19124465745567
# -2.8828435899891858
# 11.177132824677752
# -1.704094230517814
# 10.394914918811098
# -2.7347415152351258
# 11.086837832148467
# -1.8657164062502511
# 10.510495527027519
# -2.6304814803114347
# 11.019632775783325
# -1.976605952285955
# 10.585416812497122
# -2.553884220904494
# 10.967713347321473
# -2.0569130473853923
# 10.636892983927565
# -2.496508449653958
# 10.926835227677829
# -2.116828961043844
# 10.673259751604446
# -2.4531856577284152
# 10.894283522368255
# -2.1623630733399866
# 10.699245931071827
# -2.420423555701595
# 10.868144245690418
# -2.197412572603143
# 10.717815726324673
# -2.395715447823842
# 10.846990402985435
# -2.2246637223125476
# 10.730953870556764
# -2.377196447523852
# 10.829725845256908
# -2.2460422243422355
# ...

# %%
single_instance = np.array([34,0])
result = sigmoid(np.dot(single_instance, weights) + bias)
print(result)
# Out:
# [0.18420025]
